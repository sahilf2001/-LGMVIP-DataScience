# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilf2001/-LGMVIP-DataScience/blob/main/PencilSketchPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTING LIBRARY**

# %%
import cv2

# %% [markdown]
# # **READING THE IMAGE**

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("dog.jpg")
img = cv2.resize(image,(800,600))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F980D63FC10>

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F980DEC5410>

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F980DEC5110>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F980D6658D0>

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F980D653690>
# <PIL.Image.Image image mode=L size=800x600 at 0x7F980D654D50>
